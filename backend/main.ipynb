# %%
import pandas as pd

# %%
customers = pd.read_parquet("./data/raw/customers.parquet")
orders = pd.read_parquet("./data/raw/orders.parquet")
returns = pd.read_parquet("./data/raw/returns.parquet")
sessions = pd.read_parquet("./data/raw/sessions.parquet")

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   customer_id          100000 non-null  int32
#  1   signup_date          100000 non-null  datetime64[ns]
#  2   country              100000 non-null  object
#  3   acquisition_channel  100000 non-null  object
#  4   device_type          100000 non-null  object
#  5   last_order_date      85588 non-null   datetime64[ns]
#  6   is_churned           100000 non-null  bool
# dtypes: bool(1), datetime64[ns](2), int32(1), object(3)
# memory usage: 4.3+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340439 entries, 0 to 340438
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_id       340439 non-null  object
#  1   customer_id    340439 non-null  int64
#  2   order_date     340439 non-null  datetime64[ns]
#  3   order_value    340439 non-null  float64
#  4   payment_type   340439 non-null  object
#  5   discount_used  340439 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 13.3+ MB

# %%
returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27394 entries, 0 to 27393
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   return_id      27394 non-null  object
#  1   order_id       27394 non-null  object
#  2   customer_id    27394 non-null  int64
#  3   return_reason  27394 non-null  object
#  4   refund_amount  27394 non-null  float64
#  5   return_date    27394 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
sessions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060535 entries, 0 to 1060534
# Data columns (total 6 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   session_id        1060535 non-null  object
#  1   customer_id       1060535 non-null  int64
#  2   session_date      1060535 non-null  datetime64[ns]
#  3   pages_viewed      1060535 non-null  int64
#  4   session_duration  1060535 non-null  int64
#  5   source            1060535 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 48.5+ MB
